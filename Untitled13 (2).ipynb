# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.sample(n=10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 187             7.7             0.705         0.10             2.6      0.084
# 1579            6.2             0.560         0.09             1.7      0.053
# 1070            9.3             0.330         0.45             1.5      0.057
# 573            10.5             0.590         0.49             2.1      0.070
# 1333            9.1             0.775         0.22             2.2      0.079
# 493             8.7             0.690         0.31             3.0      0.086
# 1251            7.5             0.580         0.14             2.2      0.077
# 252            11.1             0.350         0.48             3.1      0.090
# 623             7.9             0.510         0.25             2.9      0.077
# 554            15.5             0.645         0.49             4.2      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# let's find here any missing values.

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# We have categorical column (Alcohal_Content), we need to convert into numeric data using enconding method.
# Content is following some order like Low,Med and High. We need to give weight accoring to the order.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_encoder = OrdinalEncoder(categories=[['Low','Median','High']])

df1 = ord_encoder.fit_transform(data[['alcohol']])
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 ord_encoder = OrdinalEncoder(categories=[['Low','Median','High']])
# ----> 3 df1 = ord_encoder.fit_transform(data[['alcohol']])
#       4 df1
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...
